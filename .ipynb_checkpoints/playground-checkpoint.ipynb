# %%
import pytorch_ssim

# %%
import cv2

# %%
import scipy.io
import scipy.io.wavfile
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
a = [1,2,3,4]

# %%
a = np.random.randn(6,1)

# %%
b = a.reshape(2, 3)
b.shape
# Out:
# (2, 3)

# %%
a = np.random.randn(2,2)
b = a.reshape(4l,-1, 1)
b.shape
# Out:
# (2, 2, 1)

# %%
type(a)
# Out:
# numpy.ndarray

# %%
print (spec0.shape)
print (spec1.shape)
# Out:
# (1, 171, 128)
# (1, 171, 128)

# %%
spec0
c = np.concatenate((spec0, spec1), axis = 0)
c = np.mean(c, axis = 0)

# %%
c.shape
# Out:
# (171, 128)

# %%
spec0 = spec[np.arange(171)*2, :].reshape(1, 171, -1)
spec1 = spec[np.arange(171)*2, :].reshape(1, 171, -1)

print (spec0.shape)
print (spec1.shape)
spec = np.mean(np.concatenate((spec0, spec1), axis = 0), axis = 0)


print (spec.shape)
# Out:
# (1, 171, 128)
# (1, 171, 128)
# (171, 128)

# %%
t = np.random.randn(1,2)
print (t)
f = np.random.randn(1,2)
np.concatenate((t,f), axis = 0)
# Out:
# [[ 2.12812937 -0.70354723]]
# array([[ 2.12812937, -0.70354723],
#        [ 0.54311927,  0.68273953]])

# %%
fs, x = scipy.io.wavfile.read('/home/tk/Documents/slice_pointsec/birdstudybook_24_7.wav') # read audio file as np array
spec, _, _, _= plt.specgram(x, Fs=fs, NFFT=2048, noverlap=1900)
plt.close('all')
cv2.imwrite("/home/tk/Documents/trytry.png", spec)
# Out:
# True

# %%
spec
# Out:
# array([[5.91251786e-02, 2.14406584e-02, 2.52722141e-03, ...,
#         9.60785469e-01, 7.87756109e-01, 3.47367257e-01],
#        [5.23467817e-01, 7.34530083e-01, 8.60597365e-01, ...,
#         2.19732150e+00, 2.30636319e+00, 2.45828578e+00],
#        [5.68479397e+00, 5.82454721e+00, 5.22584904e+00, ...,
#         1.61858834e+00, 1.92684256e+00, 1.54892683e+00],
#        ...,
#        [2.03633085e-05, 1.92768068e-05, 1.36907113e-05, ...,
#         5.34150501e-05, 4.49744925e-05, 3.20277905e-05],
#        [1.94994490e-05, 2.22847036e-05, 2.32409981e-05, ...,
#         1.17271770e-05, 2.15704753e-05, 2.93443601e-05],
#        [3.85743601e-09, 1.71484188e-06, 6.72264494e-06, ...,
#         2.81906896e-06, 5.37290607e-06, 8.80219184e-06]])

# %%
import torch

# %%
a = np.random.randn(1025, 1025)

# %%
a.shape
# Out:
# (1025, 1025)

# %%
a = 3
b = 5
np.mean(a, b)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-58-68b04b238cad> in <module>()
#       1 a = 3
#       2 b = 5
# ----> 3 np.mean(a, b)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    2918
#    2919     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2920                           out=out, **kwargs)
#    2921
#    2922
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      60
#      61     is_float16_result = False
# ---> 62     rcount = _count_reduce_items(arr, axis)
#      63     # Make this warning show up first
#      64     if rcount == 0:
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _count_reduce_items(arr, axis)
#      53     items = 1
#      54     for ax in axis:
# ...

# %%
cv2.imwrite('/home/tk/Documents/trytry.png', a)
# Out:
# True

# %%
print (spec.shape)
# Out:
# (500, 136)

# %%
a = np.array([[1,1],[2,2]])

# %%
a.shape
# Out:
# (2, 2)

# %%
a.reshape(4,1)
# Out:
# array([[1],
#        [1],
#        [2],
#        [2]])

# %%
a.shape
# Out:
# (2, 2)

# %%
spec = np.array([1,2,3,4,5,6])

# %%
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
a = spec[np.arange(2)]
print (a)
# Out:
# [1 2]

# %%
spec0  spec[np.arange()*2, :].reshape(1, )

# %%
import pytorch_ssim.__init__
from pytorch_ssim.__init__ import SSIM as SSIM
import torch
from torch.autograd import Variable
from torch import optim
import cv2
import numpy as np

npImg1 = cv2.imread("/home/tk/Documents/cocktail/pytorch-ssim/einstein.png")

img1 = torch.from_numpy(np.rollaxis(npImg1, 2)).float().unsqueeze(0)/255.0
img2 = torch.rand(img1.size())

if torch.cuda.is_available():
    img1 = img1.cuda()
    img2 = img2.cuda()

# %%
img1 = Variable( img1,  requires_grad=False)
img2 = Variable( img2, requires_grad = True)


# Functional: pytorch_ssim.ssim(img1, img2, window_size = 11, size_average = True)
ssim_value = SSIM(img1, img2).data[0]
print("Initial ssim:", ssim_value)

# Module: pytorch_ssim.SSIM(window_size = 11, size_average = True)
ssim_loss = SSIM()

optimizer = optim.Adam([img2], lr=0.01)

while ssim_value < 0.95:
    optimizer.zero_grad()
    ssim_out = -ssim_loss(img1, img2)
    ssim_value = - ssim_out.data[0]
    print(ssim_value)
    ssim_out.backward()
    optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-8ababe038519> in <module>
#       4
#       5 # Functional: pytorch_ssim.ssim(img1, img2, window_size = 11, size_average = True)
# ----> 6 ssim_value = SSIM(img1, img2).data[0]
#       7 print("Initial ssim:", ssim_value)
#       8
#
# ~/Documents/cocktail/pytorch_ssim/__init__.py in __init__(self, window_size, size_average)
#      43         self.size_average = size_average
#      44         self.channel = 1
# ---> 45         self.window = create_window(window_size, self.channel)
#      46
#      47     def forward(self, img1, img2):
#
# ~/Documents/cocktail/pytorch_ssim/__init__.py in create_window(window_size, channel)
#      10
#      11 def create_window(window_size, channel):
# ---> 12     _1D_window = gaussian(window_size, 1.5).unsqueeze(1)
# ...

# %%
# !pip install git+https://github.com/scipy/scipy.git
# Out:
# ...
#   Cloning https://github.com/scipy/scipy.git to /tmp/pip-req-build-hxygsg2k
# ...
#   Running setup.py bdist_wheel for scipy ... error
#   Complete output from command /home/tk/anaconda3/bin/python -u -c "import setuptools, tokenize;__file__='/tmp/pip-req-build-hxygsg2k/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/pip-wheel-gmgc2tn8 --python-tag cp36:
#   Cythonizing sources
#   Running scipy/special/_generate_pyx.py
#   Running scipy/linalg/_generate_pyx.py
#   Processing scipy/sparse/_csparsetools.pyx.in
#   Processing scipy/sparse/csgraph/_traversal.pyx
#   Processing scipy/sparse/csgraph/_tools.pyx
#   Processing scipy/sparse/csgraph/_shortest_path.pyx
#   Processing scipy/sparse/csgraph/_reordering.pyx
#   Processing scipy/sparse/csgraph/_min_spanning_tree.pyx
#   Processing scipy/cluster/_optimal_leaf_ordering.pyx
#   Processing scipy/cluster/_vq.pyx
# ...

# %%
# !pip install pydub
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/2f/73/bb9c093882d647437a9e6e87c7e6592d2df852f83ffac6f348b878979be0/pydub-0.23.0-py2.py3-none-any.whl
# ...

# %%
from pydub import AudioSegment
from pydub.utils import make_chunks
import os
import gc
import matplotlib.pyplot as plt
import scipy
import scipy.io.wavfile
import numpy as np
import json
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-36-f647d39fa229> in <module>
#       4 import gc
#       5 import matplotlib.pyplot as plt
# ----> 6 import scipy
#       7 import scipy.io.wavfile
#       8 import numpy as np
#
# ModuleNotFoundError: No module named 'scipy'

# %%
import scipy
import scipy.io.wavfile

wav = '/home/tk/Documents/slice_pointsec/birdstudybook_19_11.wav'
import matplotlib.pyplot as plt
import gc    

fs, x = scipy.io.wavfile.read(wav) # read audio file as np array
spec, _, _, _= plt.specgram(x, Fs=fs, NFFT=2048, noverlap=1900)
plt.close('all')
gc.collect()

spec = spec[:342, :]
spec_0 = spec[np.arange(171)*2, :].reshape(1, 171, -1)
spec_1 = spec[np.arange(171)*2 + 1, :].reshape(1, 171, -1)
spec_ = np.mean(np.concatenate((spec_0, spec_1), axis = 0), axis = 0)

spec_ = spec_[:128, :128]
mean = np.mean(spec_)
spec_ = spec_/ mean
spec_[spec_ >= 1] = 1

return spec_
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-1364d58e8772> in <module>
# ----> 1 import scipy
#       2 import scipy.io.wavfile
#       3
#       4 wav = '/home/tk/Documents/slice_pointsec/birdstudybook_19_11.wav'
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'scipy'
