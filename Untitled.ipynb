# %%
import cv2

# %%
import scipy.io
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
a = [1,2,3,4]

# %%
a = np.random.randn(6,1)

# %%
b = a.reshape(2, 3)
b.shape
# Out:
# (2, 3)

# %%
a = np.random.randn(2,2)
b = a.reshape(4l,-1, 1)
b.shape
# Out:
# (2, 2, 1)

# %%
type(a)
# Out:
# numpy.ndarray

# %%
print (spec0.shape)
print (spec1.shape)
# Out:
# (1, 171, 128)
# (1, 171, 128)

# %%
spec0
c = np.concatenate((spec0, spec1), axis = 0)
c = np.mean(c, axis = 0)

# %%
c.shape
# Out:
# (171, 128)

# %%
spec0 = spec[np.arange(171)*2, :].reshape(1, 171, -1)
spec1 = spec[np.arange(171)*2, :].reshape(1, 171, -1)

print (spec0.shape)
print (spec1.shape)
spec = np.mean(np.concatenate((spec0, spec1), axis = 0), axis = 0)


print (spec.shape)
# Out:
# (1, 171, 128)
# (1, 171, 128)
# (171, 128)

# %%
t = np.random.randn(1,2)
print (t)
f = np.random.randn(1,2)
np.concatenate((t,f), axis = 0)
# Out:
# [[ 2.12812937 -0.70354723]]
# array([[ 2.12812937, -0.70354723],
#        [ 0.54311927,  0.68273953]])

# %%
fs, x = scipy.io.wavfile.read('/home/tk/Documents/slice_pointsec/travelstoriesretold_0_10.wav') # read audio file as np array
spec, _, _, _= plt.specgram(x, Fs=fs, NFFT=2048, noverlap=1900)
print (spec.shape)
spec = spec[:342, :]
spec0 = spec[np.arange(171)*2, :].reshape(1, 171, -1)
spec1 = spec[np.arange(171)*2 + 1, :].reshape(1, 171, -1)
print (spec0.shape, spec1.shape)

spec = np.mean(np.concatenate((spec0, pec1), axis = 0), axis = 0)
print (spec.shape)
spec[:128, :128]
# Out:
# (1025, 136)
# (1, 171, 136) (1, 171, 136)
# (136,)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-151-89fea310a0d5> in <module>()
#       8 spec = np.mean(np.concatenate((spec0 + spec1), axis = 0), axis = 0)
#       9 print (spec.shape)
# ---> 10 spec[:128, :128]
#
# IndexError: too many indices for array

# %%
print (spec.shape)
# Out:
# (500, 136)

# %%
a = np.array([[1,1],[2,2]])

# %%
a.shape
# Out:
# (2, 2)

# %%
a.reshape(4,1)
# Out:
# array([[1],
#        [1],
#        [2],
#        [2]])

# %%
a.shape
# Out:
# (2, 2)

# %%
spec = np.array([1,2,3,4,5,6])

# %%
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
a = spec[np.arange(2)]
print (a)
# Out:
# [1 2]

# %%
spec0  spec[np.arange()*2, :].reshape(1, )
